# %% [markdown]
# <a href="https://colab.research.google.com/github/AleAguirreM/LEA3_Health/blob/main/a_prepocesamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive')
import numpy as np
import cv2 ### para leer imagenes jpeg
from matplotlib import pyplot as plt ## para gráfciar imágnes
import _funciones as fn #### funcion personalizada para carga de imágenes
import joblib ### para descargar array
import numpy as np

# %%
img_normal = cv2.imread('/content/drive/MyDrive/TB_Chest_Radiography_Database/train/NORMAL/Normal-2762.png')
img_tuberculosis = cv2.imread('/content/drive/MyDrive/TB_Chest_Radiography_Database/train/TUBERCULOSIS/Tuberculosis-173.png')

# %%
# Crear una figura y ejes utilizando subplots
fig, axs = plt.subplots(1, 2)

# Mostrar la primera imagen en el primer eje
axs[0].imshow(img_normal)
axs[0].set_title('normal')

# Mostrar la segunda imagen en el segundo eje
axs[1].imshow(img_tuberculosis)
axs[1].set_title('tuberculosis')

# Mostrar la figura
plt.show()

# %%
# redimensionar imagenes
imgnormal_r= cv2.resize(img_normal ,(100,100))
imgtuberculosis_r= cv2.resize(img_tuberculosis ,(100,100))

# %%
# Crear una figura y ejes utilizando subplots
fig, axs = plt.subplots(1, 2)

# Mostrar la primera imagen en el primer eje
axs[0].imshow(imgnormal_r)
axs[0].set_title('normal redimensionada')

# Mostrar la segunda imagen en el segundo eje
axs[1].imshow(imgtuberculosis_r)
axs[1].set_title('tuberculosis redimensionada')

# Mostrar la figura
plt.show()

# %%
img_normal.shape
# Out:
# (512, 512, 3)

# %%
imgnormal_r.shape
# Out:
# (100, 100, 3)

# %%
######################################################################################################
######## Código para cargar todas las imágenes reducir su tamaño y convertir en array ################
######################################################################################################

width = 100 #tamaño para reescalar imágen
num_classes = 2 #clases variable respuesta

trainpath = '/content/drive/MyDrive/TB_Chest_Radiography_Database/train/'
testpath = '/content/drive/MyDrive/TB_Chest_Radiography_Database/test/'

x_train, y_train = fn.img2data(trainpath) #Run in train
x_test, y_test = fn.img2data(testpath) #Run in train

#### convertir salidas a numpy array ####
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)
# Out:
# ...
# 100%|██████████| 700/700 [00:27<00:00, 25.62it/s]

# %%
y_train.shape
# Out:
# (3360, 1)

# %%
np.unique(y_train, return_counts= True)
# Out:
# (array([0, 1]), array([2800,  560]))

# %%
####### salidas del preprocesamiento bases listas ######
joblib.dump(x_train, "/content/drive/MyDrive/TB_Chest_Radiography_Database/salidas/x_train.pkl")
joblib.dump(y_train, "/content/drive/MyDrive/TB_Chest_Radiography_Database/salidas/y_train.pkl")
joblib.dump(x_test, "/content/drive/MyDrive/TB_Chest_Radiography_Database/salidas/x_test.pkl")
joblib.dump(y_test, "/content/drive/MyDrive/TB_Chest_Radiography_Database/salidas/y_test.pkl")
# Out:
# ['/content/drive/MyDrive/TB_Chest_Radiography_Database/salidas/y_test.pkl']
